# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("D:\water_potability.csv")

# %%
df
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 0          NaN  204.890455  20791.318981     7.300212  368.516441
# 1     3.716080  129.422921  18630.057858     6.635246         NaN
# 2     8.099124  224.236259  19909.541732     9.275884         NaN
# 3     8.316766  214.373394  22018.417441     8.059332  356.886136
# 4     9.092223  181.101509  17978.986339     6.546600  310.135738
# ...        ...         ...           ...          ...         ...
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362         NaN
# 3273  9.419510  175.762646  33155.578218     7.350233         NaN
# 3274  5.126763  230.603758  11983.869376     6.303357         NaN
# 3275  7.874671  195.102299  17404.177061     7.509306         NaN
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       564.308654       10.379783        86.990970   2.963135           0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3276 entries, 0 to 3275
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ph               2785 non-null   float64
#  1   Hardness         3276 non-null   float64
#  2   Solids           3276 non-null   float64
#  3   Chloramines      3276 non-null   float64
#  4   Sulfate          2495 non-null   float64
#  5   Conductivity     3276 non-null   float64
#  6   Organic_carbon   3276 non-null   float64
#  7   Trihalomethanes  3114 non-null   float64
#  8   Turbidity        3276 non-null   float64
#  9   Potability       3276 non-null   int64
# dtypes: float64(9), int64(1)
# memory usage: 256.1 KB

# %%
df.head()
# Out:
#          ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 0       NaN  204.890455  20791.318981     7.300212  368.516441    564.308654
# 1  3.716080  129.422921  18630.057858     6.635246         NaN    592.885359
# 2  8.099124  224.236259  19909.541732     9.275884         NaN    418.606213
# 3  8.316766  214.373394  22018.417441     8.059332  356.886136    363.266516
# 4  9.092223  181.101509  17978.986339     6.546600  310.135738    398.410813
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       10.379783        86.990970   2.963135           0
# 1       15.180013        56.329076   4.500656           0
# 2       16.868637        66.420093   3.055934           0
# 3       18.436524       100.341674   4.628771           0
# 4       11.558279        31.997993   4.075075           0

# %%
df.tail()
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362         NaN
# 3273  9.419510  175.762646  33155.578218     7.350233         NaN
# 3274  5.126763  230.603758  11983.869376     6.303357         NaN
# 3275  7.874671  195.102299  17404.177061     7.509306         NaN
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 3271    526.424171       13.894419        66.687695   4.435821           1
# 3272    392.449580       19.903225              NaN   2.798243           1
# 3273    432.044783       11.039070        69.845400   3.298875           1
# 3274    402.883113       11.168946        77.488213   4.708658           1
# 3275    327.459760       16.140368        78.698446   2.309149           1

# %%
df.drop_duplicates()
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 0          NaN  204.890455  20791.318981     7.300212  368.516441
# 1     3.716080  129.422921  18630.057858     6.635246         NaN
# 2     8.099124  224.236259  19909.541732     9.275884         NaN
# 3     8.316766  214.373394  22018.417441     8.059332  356.886136
# 4     9.092223  181.101509  17978.986339     6.546600  310.135738
# ...        ...         ...           ...          ...         ...
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362         NaN
# 3273  9.419510  175.762646  33155.578218     7.350233         NaN
# 3274  5.126763  230.603758  11983.869376     6.303357         NaN
# 3275  7.874671  195.102299  17404.177061     7.509306         NaN
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       564.308654       10.379783        86.990970   2.963135           0
# ...

# %%
df.shape
# Out:
# (3276, 10)

# %%
df.isnull().sum()
# Out:
# ph                 491
# Hardness             0
# Solids               0
# Chloramines          0
# Sulfate            781
# Conductivity         0
# Organic_carbon       0
# Trihalomethanes    162
# Turbidity            0
# Potability           0
# dtype: int64

# %%
from sklearn.impute import KNNImputer
imputer= KNNImputer()
knn_impute=imputer.fit_transform(df)
knn_impute
# Out:
# array([[7.15685690e+00, 2.04890455e+02, 2.07913190e+04, ...,
#         8.69909705e+01, 2.96313538e+00, 0.00000000e+00],
#        [3.71608008e+00, 1.29422921e+02, 1.86300579e+04, ...,
#         5.63290763e+01, 4.50065627e+00, 0.00000000e+00],
#        [8.09912419e+00, 2.24236259e+02, 1.99095417e+04, ...,
#         6.64200925e+01, 3.05593375e+00, 0.00000000e+00],
#        ...,
#        [9.41951032e+00, 1.75762646e+02, 3.31555782e+04, ...,
#         6.98454003e+01, 3.29887550e+00, 1.00000000e+00],
#        [5.12676292e+00, 2.30603758e+02, 1.19838694e+04, ...,
#         7.74882131e+01, 4.70865847e+00, 1.00000000e+00],
#        [7.87467136e+00, 1.95102299e+02, 1.74041771e+04, ...,
#         7.86984463e+01, 2.30914906e+00, 1.00000000e+00]])

# %%
knn_impute_columns=imputer.get_feature_names_out()
knn_impute_columns
# Out:
# array(['ph', 'Hardness', 'Solids', 'Chloramines', 'Sulfate',
#        'Conductivity', 'Organic_carbon', 'Trihalomethanes', 'Turbidity',
#        'Potability'], dtype=object)

# %%
knn_impute=pd.DataFrame(knn_impute)
knn_impute
# Out:
#              0           1             2         3           4           5  \
# 0     7.156857  204.890455  20791.318981  7.300212  368.516441  564.308654
# 1     3.716080  129.422921  18630.057858  6.635246  336.094350  592.885359
# 2     8.099124  224.236259  19909.541732  9.275884  330.449166  418.606213
# 3     8.316766  214.373394  22018.417441  8.059332  356.886136  363.266516
# 4     9.092223  181.101509  17978.986339  6.546600  310.135738  398.410813
# ...        ...         ...           ...       ...         ...         ...
# 3271  4.668102  193.681735  47580.991603  7.166639  359.948574  526.424171
# 3272  7.808856  193.553212  17329.802160  8.061362  364.091541  392.449580
# 3273  9.419510  175.762646  33155.578218  7.350233  327.357588  432.044783
# 3274  5.126763  230.603758  11983.869376  6.303357  325.952434  402.883113
# 3275  7.874671  195.102299  17404.177061  7.509306  345.728295  327.459760
#
#               6           7         8    9
# ...

# %%
knn_impute.columns=knn_impute_columns
knn_impute
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 0     7.156857  204.890455  20791.318981     7.300212  368.516441
# 1     3.716080  129.422921  18630.057858     6.635246  336.094350
# 2     8.099124  224.236259  19909.541732     9.275884  330.449166
# 3     8.316766  214.373394  22018.417441     8.059332  356.886136
# 4     9.092223  181.101509  17978.986339     6.546600  310.135738
# ...        ...         ...           ...          ...         ...
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362  364.091541
# 3273  9.419510  175.762646  33155.578218     7.350233  327.357588
# 3274  5.126763  230.603758  11983.869376     6.303357  325.952434
# 3275  7.874671  195.102299  17404.177061     7.509306  345.728295
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       564.308654       10.379783        86.990970   2.963135         0.0
# ...

# %%
knn_impute.isnull().sum()
# Out:
# ph                 0
# Hardness           0
# Solids             0
# Chloramines        0
# Sulfate            0
# Conductivity       0
# Organic_carbon     0
# Trihalomethanes    0
# Turbidity          0
# Potability         0
# dtype: int64

# %%
knn_impute.describe()
# Out:
#                 ph     Hardness        Solids  Chloramines      Sulfate  \
# count  3276.000000  3276.000000   3276.000000  3276.000000  3276.000000
# mean      7.078167   196.369496  22014.092526     7.122277   333.605767
# std       1.497228    32.879761   8768.570828     1.583085    37.453055
# min       0.000000    47.432000    320.942611     0.352000   129.000000
# 25%       6.187017   176.850538  15666.690297     6.127421   312.389295
# 50%       7.052221   196.967627  20927.833607     7.130299   333.255192
# 75%       7.948570   216.667456  27332.762127     8.114887   355.013586
# max      14.000000   323.124000  61227.196008    13.127000   481.030642
#
#        Conductivity  Organic_carbon  Trihalomethanes    Turbidity   Potability
# count   3276.000000     3276.000000      3276.000000  3276.000000  3276.000000
# mean     426.205111       14.284970        66.403218     3.966786     0.390110
# std       80.824064        3.308162        15.837754     0.780382     0.487849
# ...

# %%
plt.figure(figsize=(10,5))
sns.boxplot(knn_impute)
# Out:
# <Axes: >

# %%
knn_impute.median()
# Out:
# ph                     7.052221
# Hardness             196.967627
# Solids             20927.833607
# Chloramines            7.130299
# Sulfate              333.255192
# Conductivity         421.884968
# Organic_carbon        14.218338
# Trihalomethanes       66.603114
# Turbidity              3.955028
# Potability             0.000000
# dtype: float64

# %%
q1=knn_impute.quantile(0.25)
q1
# Out:
# ph                     6.187017
# Hardness             176.850538
# Solids             15666.690297
# Chloramines            6.127421
# Sulfate              312.389295
# Conductivity         365.734414
# Organic_carbon        12.065801
# Trihalomethanes       56.409254
# Turbidity              3.439711
# Potability             0.000000
# Name: 0.25, dtype: float64

# %%
q3=knn_impute.quantile(0.75)
q3
# Out:
# ph                     7.948570
# Hardness             216.667456
# Solids             27332.762127
# Chloramines            8.114887
# Sulfate              355.013586
# Conductivity         481.792304
# Organic_carbon        16.557652
# Trihalomethanes       76.843337
# Turbidity              4.500320
# Potability             1.000000
# Name: 0.75, dtype: float64

# %%
IQR=q3-q1
IQR
# Out:
# ph                     1.761553
# Hardness              39.816918
# Solids             11666.071830
# Chloramines            1.987466
# Sulfate               42.624291
# Conductivity         116.057890
# Organic_carbon         4.491850
# Trihalomethanes       20.434083
# Turbidity              1.060609
# Potability             1.000000
# dtype: float64

# %%
lower_range= q1-(1.5*IQR)
lower_range
# Out:
# ph                    3.544687
# Hardness            117.125160
# Solids            -1832.417449
# Chloramines           3.146221
# Sulfate             248.452858
# Conductivity        191.647579
# Organic_carbon        5.328026
# Trihalomethanes      25.758130
# Turbidity             1.848797
# Potability           -1.500000
# dtype: float64

# %%
upper_range = q3 + (1.5*IQR)
upper_range
# Out:
# ph                    10.590900
# Hardness             276.392834
# Solids             44831.869873
# Chloramines           11.096086
# Sulfate              418.950022
# Conductivity         655.879140
# Organic_carbon        23.295427
# Trihalomethanes      107.494462
# Turbidity              6.091233
# Potability             2.500000
# dtype: float64

# %%
# Trimming 
knn_impute=knn_impute[(knn_impute >lower_range)&(knn_impute <upper_range)]
knn_impute
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 0     7.156857  204.890455  20791.318981     7.300212  368.516441
# 1     3.716080  129.422921  18630.057858     6.635246  336.094350
# 2     8.099124  224.236259  19909.541732     9.275884  330.449166
# 3     8.316766  214.373394  22018.417441     8.059332  356.886136
# 4     9.092223  181.101509  17978.986339     6.546600  310.135738
# ...        ...         ...           ...          ...         ...
# 3271  4.668102  193.681735           NaN     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362  364.091541
# 3273  9.419510  175.762646  33155.578218     7.350233  327.357588
# 3274  5.126763  230.603758  11983.869376     6.303357  325.952434
# 3275  7.874671  195.102299  17404.177061     7.509306  345.728295
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       564.308654       10.379783        86.990970   2.963135         0.0
# ...

# %%
sns.boxplot(knn_impute)
# Out:
# <Axes: >

# %%
knn_impute.isnull().sum()
# Out:
# ph                  79
# Hardness            83
# Solids              47
# Chloramines         61
# Sulfate            115
# Conductivity        11
# Organic_carbon      25
# Trihalomethanes     49
# Turbidity           19
# Potability           0
# dtype: int64

# %%
df1=knn_impute.dropna()

# %%
df1
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 0     7.156857  204.890455  20791.318981     7.300212  368.516441
# 1     3.716080  129.422921  18630.057858     6.635246  336.094350
# 2     8.099124  224.236259  19909.541732     9.275884  330.449166
# 3     8.316766  214.373394  22018.417441     8.059332  356.886136
# 4     9.092223  181.101509  17978.986339     6.546600  310.135738
# ...        ...         ...           ...          ...         ...
# 3270  6.069616  186.659040  26138.780191     7.747547  345.700257
# 3272  7.808856  193.553212  17329.802160     8.061362  364.091541
# 3273  9.419510  175.762646  33155.578218     7.350233  327.357588
# 3274  5.126763  230.603758  11983.869376     6.303357  325.952434
# 3275  7.874671  195.102299  17404.177061     7.509306  345.728295
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       564.308654       10.379783        86.990970   2.963135         0.0
# ...

# %%
df1.isnull().sum()
# Out:
# ph                 0
# Hardness           0
# Solids             0
# Chloramines        0
# Sulfate            0
# Conductivity       0
# Organic_carbon     0
# Trihalomethanes    0
# Turbidity          0
# Potability         0
# dtype: int64

# %%
df1.describe()
# Out:
#                 ph     Hardness        Solids  Chloramines      Sulfate  \
# count  2846.000000  2846.000000   2846.000000  2846.000000  2846.000000
# mean      7.063346   196.666005  21594.780244     7.102673   333.840960
# std       1.313608    28.843356   8023.560147     1.423626    31.979089
# min       3.590822   117.791230    320.942611     3.194969   248.711963
# 25%       6.249429   178.327855  15614.235044     6.164192   313.847629
# 50%       7.038220   197.335425  20756.434020     7.104785   333.435698
# 75%       7.880400   215.567297  26892.067402     8.057910   353.524601
# max      10.581386   275.886513  44652.363872    11.086526   418.494244
#
#        Conductivity  Organic_carbon  Trihalomethanes    Turbidity   Potability
# count   2846.000000     2846.000000      2846.000000  2846.000000  2846.000000
# mean     425.688644       14.313089        66.447787     3.967381     0.377372
# std       80.114031        3.209055        15.015913     0.760417     0.484814
# ...

# %%
plt.figure(figsize=(30,30))
sns.heatmap(df1.corr(),annot=True)
# Out:
# <Axes: >

# %%
X=df1.drop('Potability',axis=1).copy()
Y=df1['Potability'].copy()

# %%
from sklearn.preprocessing import MinMaxScaler,StandardScaler
min_scaler=MinMaxScaler()
X=min_scaler.fit_transform(X)
min_X=pd.DataFrame(X)
min_X
# Out:
#              0         1         2         3         4         5         6  \
# 0     0.510121  0.550929  0.461758  0.520207  0.705636  0.804335  0.280742
# 1     0.017918  0.073574  0.413005  0.435944  0.514673  0.867709  0.549332
# 2     0.644912  0.673297  0.441867  0.770560  0.481424  0.481211  0.643817
# 3     0.676046  0.610911  0.489438  0.616401  0.637135  0.358484  0.731546
# 4     0.786975  0.400456  0.398319  0.424711  0.361780  0.436423  0.346683
# ...        ...       ...       ...       ...       ...       ...       ...
# 2841  0.354591  0.435610  0.582382  0.576892  0.571251  0.475180  0.375183
# 2842  0.603390  0.479217  0.383675  0.616658  0.679574  0.423203  0.813613
# 2843  0.833794  0.366687  0.740663  0.526546  0.463215  0.511013  0.317632
# 2844  0.219716  0.713573  0.263085  0.393888  0.454938  0.446342  0.324899
# 2845  0.612805  0.489016  0.385353  0.546703  0.571416  0.279075  0.603068
#
#              7         8
# 0     0.749704  0.258967
# ...

# %%
standard_scaler=StandardScaler()
X=standard_scaler.fit_transform(min_X)
standard_X=pd.DataFrame(X)
standard_X
# Out:
#              0         1         2         3         4         5         6  \
# 0     0.071199  0.285192 -0.100155  0.138782  1.084508  1.730588 -1.225905
# 1    -2.548595 -2.331729 -0.369567 -0.328394  0.070477  2.087351  0.270197
# 2     0.788637  0.956030 -0.210073  1.526800 -0.106082 -0.088420  0.796495
# 3     0.954349  0.614024  0.052808  0.672106  0.720759 -0.779303  1.285164
# 4     1.544779 -0.539716 -0.450726 -0.390672 -0.741403 -0.340547 -0.858600
# ...        ...       ...       ...       ...       ...       ...       ...
# 2841 -0.756622 -0.347003  0.566432  0.453060  0.370911 -0.122368 -0.699852
# 2842  0.567628 -0.107940 -0.531650  0.673532  0.946115 -0.414970  1.742295
# 2843  1.793974 -0.724847  1.441110  0.173924 -0.202773  0.079353 -1.020423
# 2844 -1.474507  1.176830 -1.198047 -0.561564 -0.246721 -0.284713 -0.979944
# 2845  0.617740 -0.054223 -0.522379  0.285682  0.371787 -1.226329  0.569514
#
#              7         8
# 0     1.368335 -1.320883
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
# Step 1: Split the scaled data into training and testing sets
X_train, X_test, Y_train, Y_test = train_test_split(standard_X, Y, test_size=0.2, random_state=42)

# %%
# Step 2: Initialize the SVM classifier
svm = SVC()

# %%
# Step 3: Train the SVM classifier using the training data
svm.fit(X_train, Y_train)
# Out:
# SVC()

# %%
# Step 4: Make predictions on the testing set
Y_pred = svm.predict(X_test)

# %%
# Step 5: Evaluate the performance of the SVM classifier
accuracy = accuracy_score(Y_test, Y_pred)
precision = precision_score(Y_test, Y_pred)
recall = recall_score(Y_test, Y_pred)
f1 = f1_score(Y_test, Y_pred)

# %%
# Print the evaluation metrics
print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1)
# Out:
# Accuracy: 0.6754385964912281
# Precision: 0.6136363636363636
# Recall: 0.2634146341463415
# F1-score: 0.36860068259385664
